# %%
import csv

# %%
import nltk

# %%
import numpy as np

# %%
import pandas as pd

# %%
import sklearn.feature_extraction.text

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn import metrics

# %%
import scipy

# %%
import string

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.corpus import stopwords

# %%
#Opening the file

# %%
the_data = pd.read_csv("all_reviews.csv")

# %%
# Randomizing the rows in the file

# %%
the_data = the_data.reindex(np.random.permutation(the_data.index))

# %%
# Total instances in the csv data, pre-sorting into train and test.
good = 0
bad = 0
for item in the_data['good/bad']:
    if item == 'bad':
        bad += 1
    if item == 'good':
        good += 1
print('Good: ' + str(good))
print('Bad: ' + str(bad))
# Out:
# Good: 96
# Bad: 85

# %%
# Create a new dataframe with modified star value & a cleaned up review

# %%
data = []
for index, row in the_data.iterrows():
    sentence = ""
    # extract the review from the original
    review = row['review']
    # split into words
    tokens = word_tokenize(review)
    # convert to lowercase
    tokens = [w.lower() for w in tokens]
    # remove punctuation and abberations
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    words = [word for word in stripped if word.isalpha()]
    # filter out stop words & join in a sentence
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if w not in stop_words]
    sentence = ' '.join(words)
    data.append({'stars': (row['stars']) / 10,
                      'review': sentence,
                      'good/bad': row['good/bad']})
new_frame = pd.DataFrame(data)
# Out:
#     good/bad                                             review  stars
# 0        bad                               major disappointment    0.5
# 1       good  think one best films whole movie although film...    5.0
# 2        bad  ok film poor star wars lazy writing character ...    1.0
# 3        bad  great film mark hamill turns performance caree...    5.0
# 4       good  best star wars film ever new trilogy taking st...    5.0
# 5        bad  never took critics wrong rian blew opportunity...    2.0
# 6       good  feel disturbance force movie light saber fight...    1.0
# 7       good  expected great movie resets star wars universe...    5.0
# 8       good  absolutely worst star wars movie thought tfa b...    0.5
# 9       good  movie completely annihilated beloved franchise...    0.5
# 10       bad       sucked rian johnson even watch force awakens    0.5
# 11      good  plot holes mishandling key star wars universe ...    0.5
# 12       bad                    phenomenal best movie franchise    5.0
# 13       bad  dissapointing star wars universe craptastic ve...    2.5
# 14       bad  loved fantastic storytelling visuals spectacle...    5.0
# 15       bad                         movie sucked total letdown    0.5
# 16       bad  rian ruined star wars could written better sto...    0.5
# 17       bad  though poor humor scenes nt feel like belonged...    4.0
# 18      good  nt think deeply plot characterizations foundat...    3.0
# 19       bad  nt listen negative discussion online movie gre...    4.0
# 20      good  visually great scenes hands pretty much story ...    2.0
# 21       bad       good movie nt deserve vitriolic hate getting    4.0
# 22       bad  fan since original episode iv young lad movie ...    5.0
# 23      good  glorious visuals good acting save painfully ba...    2.5
# 24       bad  nt understand really tell plot movie wait try ...    1.0
# 25       bad  made account write review movie best star wars...    5.0
# 26      good  rotten tomatoes critics complete sell outs way...    1.0
# 27      good  arguably worst star wars film ever made plot c...    1.0
# 28       bad                                     loved expected    5.0
# 29       bad  liked lot sw fan super fan never read books pl...    4.0
# ..       ...                                                ...    ...
# 151     good  horrendous social justice nightmare every whit...    0.5
# 152     good  star wars last jedi one best star wars movies ...    4.5
# 153     good  disney opera bombastic special effects lots gr...    1.0
# 154      bad  disney killed star wars poor attempt star wars...    4.5
# 155     good  movie wanted see technically beautifully shot ...    3.0
# 156      bad                unwatchable garbage offensively bad    0.5
# 157     good  star music effects cinematography throw enough...    0.5
# 158      bad  genuinely bad space gravity would nt arc energ...    0.5
# 159      bad  disappointing garbage thing movie episode jarj...    1.0
# 160     good  awful movie start finish storyline ridiculous ...    0.5
# 161      bad  silver lining coolest lightsaber battle ever r...    0.5
# 162     good  visuals amazing sound engineering great almost...    1.0
# 163      bad  film piece shit rian johnson simply destroyed ...    0.5
# 164      bad  story nt make sense like decided ignore everyt...    2.0
# 165      bad  way many plot holes pathetic ending star wars ...    1.0
# 166      bad  super disappointed waiting long time movie tur...    0.5
# 167      bad  way many plot holes totally rips apart everyth...    1.0
# 168     good  movie terrible plot acters suck sorry say walt...    0.5
# 169     good  last jedi hours minutes long minutes deep narr...    2.5
# 170      bad  great movie nt sky high expectations want movi...    5.0
# 171      bad  seen trailers expectations movie trying best g...    1.5
# 172     good  biggest problem film plot holes regardless die...    2.0
# 173     good  complete waste ingredients everything good fil...    2.0
# 174      bad      emotionally powerful scenes star wars history    5.0
# 175     good  liking movie means probably suffer cognitive d...    0.5
# 176      bad  movie ok nothing special made dislike characte...    2.5
# 177      bad  absolute travesty mark hamillthis borderline k...    0.5
# 178     good  like watching spaceballs turned star wars movi...    1.0
# 179      bad  one point necessary cut umbilical cord best fi...    4.5
# 180      bad                       movie really good kids loved    0.5
#
# [181 rows x 3 columns]

# %%
#Extracting features from text, define target y and data x

# %%
vect = TfidfVectorizer()
X = vect.fit_transform(new_frame['review'])
Y = new_frame['good/bad']

# %% [raw]
# new_frame

# %%
#Partitioning the data into test and training set
split = 0.75
split_size = int(len(Y)*split)

X_train = X[:split_size]
X_test = X[split_size:]

Y_train = Y[:split_size]
Y_test = Y[split_size:]

# %%
#Test data numbers
test_good = 0
test_bad = 0 

for rating in Y_test:
    if rating == 'good':
        test_good += 1
    if rating == 'bad':
        test_bad += 1
print('Good reviews in test data: ' + str(test_good))
print('Bad reviews in test data: ' + str(test_bad))
# Out:
# Good reviews in test data: 22
# Bad reviews in test data: 24

# %%
# Training the model

# %%
clf = MultinomialNB()
clf.fit(X, Y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# Evaluating the results

# %%
# Accuracy on training set
print(clf.score(X_train, Y_train))
# Out:
# 0.97037037037

# %%
# Accuracy on testing set
print(clf.score(X_test, Y_test))
# Out:
# 1.0

# %%
Y_test
# Out:
# 135     bad
# 136    good
# 137     bad
# 138     bad
# 139    good
# 140     bad
# 141     bad
# 142     bad
# 143    good
# 144     bad
# 145     bad
# 146    good
# 147     bad
# 148     bad
# 149     bad
# 150     bad
# 151     bad
# 152     bad
# 153    good
# 154     bad
# 155    good
# 156     bad
# 157    good
# 158     bad
# 159    good
# 160     bad
# 161     bad
# 162     bad
# 163    good
# 164    good
# 165    good
# 166    good
# 167     bad
# 168    good
# 169    good
# 170     bad
# 171     bad
# 172     bad
# 173    good
# 174    good
# 175    good
# 176    good
# 177     bad
# 178     bad
# 179     bad
# 180     bad
# Name: good/bad, dtype: object

# %%
Y_pred = clf.predict(X_test)
print(metrics.classification_report(Y_test, Y_pred))
# Out:
#              precision    recall  f1-score   support
#
#         bad       1.00      1.00      1.00        24
#        good       1.00      1.00      1.00        22
#
# avg / total       1.00      1.00      1.00        46

# %%
Y_pred
# Out:
# array(['good', 'good', 'good', 'bad', 'bad', 'good', 'bad', 'bad', 'good',
#        'good', 'bad', 'good', 'bad', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'good', 'bad', 'good', 'bad', 'bad', 'good', 'bad',
#        'good', 'bad', 'bad', 'bad', 'bad', 'bad', 'good', 'good', 'bad',
#        'bad', 'good', 'good', 'bad', 'good', 'bad', 'bad', 'good', 'bad',
#        'bad'],
#       dtype='<U4')

# %%
#Messing around to see what we can pull.

# %%
# Testing it on new data

# %%
test = ['This is nothing but a Chick Flick in Space, should be called Rainbow Wars,']

# %%
t_test = vect.transform(test)

# %%
y_pred = clf.predict(t_test)

# %%
# Out:
#      stars  good/bad                                             review
# 0        5       NaN    I went in with high hopes. I was a huge fan ...
# 1        5       NaN    Poor story. Some very dodgy CG and way too m...
# 2        5       NaN    Disney destroyed 40 years worth of classic s...
# 3        5       NaN    Devastated at how bad this movie was. Awful,...
# 4        5       NaN    It was awful. I feel bad for the pointless c...
# 5        5       NaN    Absolutely the worst Star Wars movie to date...
# 6        5       NaN    Had some great moments but zero character de...
# 7        5       NaN    ???? ?? ? ????????? ??????? ????????????? ??...
# 8        5       NaN    Such a disappointing plot, storyline, and ch...
# 9        5       NaN    I really wanted to leave a 1,000+ page revie...
# 10       5       NaN    When you read the expanded universe books an...
# 11       5       NaN    I usually don't do movie reviews, but I'm ma...
# 12       5       NaN    They killed luke off too quickly and without...
# 13       5       NaN    Rian/Disney! You took my childhood and wiped...
# 14       5       NaN    Terrible movie. You can tell the director ha...
# 15       5       NaN    Cool special effects but ruined through horr...
# 16       5       NaN    This is the worst StarWars movie ever. The o...
# 17       5       NaN    Don't even get me started, awful on so many ...
# 18       5       NaN    Best to worst1. Empire strikes back2. Return...
# 19       5       NaN    Instead of character development and solid s...
# 20       5       NaN    Star Wars TLJ exemplifies the effect that co...
# 21       5       NaN    Worst Star Wars movie ever. Destroys the Sta...
# 22       5       NaN    HALF OF THIS MOVIE SHOULD HAVE BEEN CUT OUT....
# 23       5       NaN    Laughable writing, cringy "comedic relief" a...
# 24       5       NaN    For me it is simple, it is the movie that I ...
# 25       5       NaN    I thought this movie was awful, and a slap i...
# 26       5       NaN                       Absolutely trash, f u Disney
# 27       5       NaN    This movie doesn't require you suspend disbe...
# 28       5       NaN    Total rubbish and utterly disappointing! I h...
# 29       5       NaN    The Last Jedi was a stinging disappointment....
# ..     ...       ...                                                ...
# 660     50       NaN    This is not going to go the way you think! A...
# 661     50       NaN    Sorry fanboys but this is the where the fran...
# 662     50       NaN    AMAZING MOVIE!!! One of the best!!! STAR WAR...
# 663     50       NaN    Failure was a thematic necessity in this fil...
# 664     50       NaN    Rian Johnson brings a new and enjoyable take...
# 665     50       NaN    Greatest movie yet I have seen, pure emotion...
# 666     50       NaN    Loved it - enjoy it as entertainment. Just b...
# 667     50       NaN    With this movie, Rian Johnson truly gives us...
# 668     50       NaN               The Best Star Wars Movie of all time
# 669     50       NaN    Maybe it was the nostalgia but I could not d...
# 670     50       NaN    Fantastic addition to the franchise, ryan Jo...
# 671     50       NaN    It's a fun movie that has some issues but is...
# 672     50       NaN    Loved it lifetime star wars fan and I'm not ...
# 673     50       NaN    It's fun, it's visually stunning, it takes r...
# 674     50       NaN    It is Star Wars. It is great. Shock - horror...
# 675     50       NaN    I absolutely loved this movie. I understand ...
# 676     50       NaN                            Heroic....truly heroic.
# 677     50       NaN    Excellent chapter in the Star Wars legacy!! ...
# 678     50       NaN    Excellent movie. Beautiful cinematography. G...
# 679     50       NaN    I had a lot to say about this fllm, but most...
# 680     50       NaN    Clearly, everyone has an opinion on The Last...
# 681     50       NaN    The Last Jedi was different then any other S...
# 682     50       NaN    It was a great movie that left you wanting m...
# 683     50       NaN    I absolutely loved this movie! Losing anothe...
# 684     50       NaN    SPOILERS SPOILERS SPOILERS OMG! BRILLIANT! B...
# 685     50       NaN    In short I loved it, very bold, interesting ...
# 686     50       NaN    I really loved the film, even the fact that ...
# 687     50       NaN    As good of a movie as possible. Excitement, ...
# 688     50       NaN    I saw the original Star Wars movie on its re...
# 689     50       NaN    Great movie, saw the original when I was 11 ...
#
# [690 rows x 3 columns]

# %%
# Predicting quality of unsorted data

# %%
#Importing
feature_data = pd.read_csv("test2.csv")

# %%
# This is to test the data is importing correctly
feature_good = 0
feature_bad = 0
for item in feature_data['stars']:
    if item >= 25:
        feature_good += 1
    else:
        feature_bad += 1
print('Positive Reviews: ' + str(feature_good))
print('Negative Reviews: ' + str(feature_bad))
# Out:
# Positive Reviews: 279
# Negative Reviews: 411

# %%
# Cleaning
feature_list = []
for index, row in feature_data.iterrows():
    sentence = ""
    # extract the review from the original
    review = row['review']
    # split into words
    tokens = word_tokenize(review)
    # convert to lowercase
    tokens = [w.lower() for w in tokens]
    # remove punctuation and abberations
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    words = [word for word in stripped if word.isalpha()]
    # filter out stop words & join in a sentence
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if w not in stop_words]
    sentence = ' '.join(words)
    feature_list.append({'stars': (row['stars']) / 10,
                      'review': sentence,
                      'good/bad': row['good/bad']})
feature_frame = pd.DataFrame(feature_list)

# %%
feature_test = vect.transform(feature_frame)

# %%
new_y_pred = clf.predict(feature_test)

# %%
feature_test
# Out:
# <3x2424 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>

# %%
new_y_test = feature_frame['good/bad']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\patti\codefellows\2nd_half\reviews-to-improve\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'good/bad'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-294-419844087fdb> in <module>()
# ----> 1 new_y_test = feature_frame['good/bad']
#
# c:\users\patti\codefellows\2nd_half\reviews-to-improve\env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# c:\users\patti\codefellows\2nd_half\reviews-to-improve\env\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# c:\users\patti\codefellows\2nd_half\reviews-to-improve\env\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# c:\users\patti\codefellows\2nd_half\reviews-to-improve\env\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\users\patti\codefellows\2nd_half\reviews-to-improve\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'good/bad'
